# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
import torchvision.transforms.functional as TF
import torch.utils.data as data
from torch.utils.data import DataLoader, TensorDataset
import pickle
import time
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, roc_curve, roc_auc_score, precision_recall_curve, auc
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# #Cargar datos y exploración

# %%
with open('/content/drive/MyDrive/Colab Notebooks/td_ztf_stamp_17_06_20.pkl', 'rb') as file:
    data = pickle.load(file)

print(type(data))
print(data.keys())
# Out:
# <class 'dict'>
# dict_keys(['Train', 'Validation', 'Test'])

# %%
train_data = data["Train"]

# Si train_data es un DataFrame:
if isinstance(train_data, pd.DataFrame):
    print(train_data.head())
    print(train_data.info())
else:
    print(type(train_data))
# Out:
# <class 'dict'>

# %%
print(train_data.keys())

# %% [markdown]
# #Pre procesamiento de datos

# %%
# Cargar los datos
train_data = data["Train"]
val_data = data["Validation"]
test_data = data["Test"]

# Convertir los datos de entrenamiento a un tensor de PyTorch.
train_images = torch.from_numpy(train_data["images"])
train_labels = torch.from_numpy(train_data["labels"])

# Convertir los datos de validación a un tensor de PyTorch.
val_images = torch.from_numpy(val_data["images"])
val_labels = torch.from_numpy(val_data["labels"])

# Convertir los datos de prueba a un tensor de PyTorch.
test_images = torch.from_numpy(test_data["images"])
test_labels = torch.from_numpy(test_data["labels"])

# %%
# Cambiar la forma de los datos de entrada
train_images = train_images.permute(0, 3, 1, 2)
val_images = val_images.permute(0, 3, 1, 2)
test_images = test_images.permute(0, 3, 1, 2)

# %%
# Aplicar recorte al centro
def center_crop_images(images):
    cropped_images = TF.center_crop(images, (21, 21))
    return cropped_images

# %%
# Aplicar el preprocesamiento a los conjuntos de entrenamiento, validación y prueba
train_images = center_crop_images(train_images)
val_images = center_crop_images(val_images)
test_images = center_crop_images(test_images)

# Crear dataloader de entrenamiento
train_dataset = TensorDataset(train_images, train_labels)
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)

# Crear dataloader de validación
val_dataset = TensorDataset(val_images, val_labels)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)

# Crear dataloader de prueba
test_dataset = TensorDataset(test_images, test_labels)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# %% [markdown]
# Agregar capas convolucionales después de las capas de max-pooling se hace comúnmente para permitir que la red capture características más complejas y abstractas a medida que se avanza en la arquitectura.
#
# 1. **Expansión del campo receptivo:** Después de aplicar max-pooling, el campo receptivo de las neuronas en las capas siguientes se ha expandido. Agregar capas convolucionales adicionales después de max-pooling permite que estas nuevas capas capturen patrones más grandes y complejos en el espacio de entrada. Esto es especialmente útil si las características relevantes para la detección de supernovas tienen un alcance más amplio en la imagen.
#
# 2. **Captura de jerarquía de características:** Las capas convolucionales adicionales después de max-pooling pueden ayudar a capturar una jerarquía de características. Las primeras capas convolucionales pueden aprender características de bajo nivel, como bordes y texturas, mientras que las capas convolucionales adicionales pueden aprender características de nivel más alto y abstractas que se construyen sobre las características de las capas anteriores.
#
# 3. **Mejora de la capacidad representacional:** Agregar capas convolucionales adicionales aumenta la capacidad del modelo para representar funciones más complejas y no lineales. Esto puede ser beneficioso para la detección de supernovas, donde las características relevantes pueden tener formas y patrones diversos.
#
# 4. **Aprendizaje de representaciones más abstractas:** A medida que avanzamos en las capas convolucionales, las representaciones se vuelven más abstractas y específicas para el problema en cuestión. Agregar capas convolucionales después del max-pooling permite que la red aprenda representaciones más abstractas y específicas para las características astronómicas que podrían ser cruciales para la detección de supernovas.

# %% [markdown]
# #Modelo Crop, sin ZPadd + Capas convolucionales adicionales

# %% [markdown]
# # Arquitectura Capas Adicionales
#
# | Capa | Tipo de Capa                | Entradas | Salidas | Kernel/Pool | Stride | Padding |
# |------|-----------------------------|----------|---------|-------------|--------|---------|
# | 1    | Rotaciones                  | 3        | 3       | 3x3         | 1      | 1       |
# | 2    | Conv1                       | 3        | 32      | 4x4         | 1      | 2       |
# | 3    | Conv2                       | 32       | 32      | 3x3         | 1      | 1       |
# | 4    | MaxPool1                     | -       | -       | 2x2         | 2      | -       |
# | 5    | Conv3                       | 32       | 64      | 3x3         | 1      | 1       |
# | 6    | Conv4                       | 64       | 64      | 3x3         | 1      | 1       |
# | 7    | Conv5                       | 64       | 64      | 3x3         | 1      | 1       |
# | 8    | MaxPool2                     | -       | -       | 2x2         | 2      | -       |
# | 9    | Conv6                       | 64       | 128     | 3x3         | 1      | 1       |
# | 10   | Conv7                       | 128      | 128     | 3x3         | 1      | 1       |
# | 11   | Conv8                       | 128      | 128     | 3x3         | 1      | 1       |
# | 12   | MaxPool3                     | -       | -       | 2x2         | 2      | -       |
# | 13   | Cyclic Pooling              | -       | -       | -           | -      | -       |
# | 14   | Flatten                     | -       | -       | -           | -      | -       |
# | 15   | Dense1                      | 256      | 64      | -           | -      | -       |
# | 16   | Dense2                      | 64       | 64      | -           | -      | -       |
# | 17   | Salida                      | 64       | 5       | -           | -      | -       |
# | 18   | Dropout                     | -       | -       | -           | -      | -       |

# %%
#Rotaciones
def RotAugmentation(x_0):
    #print(x_0[1,1,:,:].shape)
    x_1 = x_0
    x_2 = x_0
    x_3 = x_0

    for i in range (x_0.shape[0]):
      for j in range (3):
        x_1[i,j,:,:] = torch.rot90(x_0[i,j,:,:], 1, [0,1])
        x_2[i,j,:,:] = torch.rot90(x_0[i,j,:,:], 2, [0,1])
        x_3[i,j,:,:] = torch.rot90(x_0[i,j,:,:], 3, [0,1])

    return [x_0,x_1,x_2,x_3]

# %%
class CyclicPool(nn.Module):
    def __init__(self, in_channels):
        super(CyclicPool, self).__init__()
        self.in_channels = in_channels
        self.avg_pool = nn.AvgPool2d(kernel_size=2, stride=2)
        self.max_pool = nn.MaxPool2d(kernel_size=2, stride=2)

    def forward(self, x):
        x_avg = self.avg_pool(x)
        x_max = self.max_pool(x)
        x = torch.cat([x_avg, x_max], dim=1)
        return x

# %%
class SupernovaDetector(nn.Module):
    def __init__(self):
        super(SupernovaDetector, self).__init__()
        # Rotaciones
        self.rotation = nn.Sequential(
            nn.Conv2d(3, 3, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.Conv2d(3, 3, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
        )

        # Capas Convolucionales
        self.conv1 = nn.Conv2d(3, 32, kernel_size=4, stride=1, padding=2)
        self.conv2 = nn.Conv2d(32, 32, kernel_size=3, stride=1, padding=1)
        # Max-pooling
        self.pool1 = nn.MaxPool2d(2, 2)
        # Capas Convolucionales adicionales
        self.conv3 = nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1)
        self.conv4 = nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=1)
        self.conv5 = nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=1)
        # Max-pooling
        self.pool2 = nn.MaxPool2d(2, 2)
        # Capas Convolucionales adicionales
        self.conv6 = nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1)
        self.conv7 = nn.Conv2d(128, 128, kernel_size=3, stride=1, padding=1)
        self.conv8 = nn.Conv2d(128, 128, kernel_size=3, stride=1, padding=1)
        # Max-pooling
        self.pool3 = nn.MaxPool2d(2, 2)
        # Cyclic pooling
        self.cyclic_pool = CyclicPool(128)
        # Flatten
        self.flatten = nn.Flatten()
        # Dense layer (FC)
        self.dense1 = nn.Linear(256, 64)
        self.dense2 = nn.Linear(64, 64)
        # Output dropout softmax
        self.output_layer = nn.Linear(64, 5)
        self.dropout = nn.Dropout(p=0.5)

    def forward(self, x):
       # Aplicar rotaciones al inicio
        x_rotated_list = RotAugmentation(x)
        # Concatenar a lo largo de la dimensión del lote (batch dimension)
        x_rotated = torch.cat(x_rotated_list, dim=0)
        x = self.conv1(x)  # Capas Convolucionales
        x = F.relu(x)
        x = self.conv2(x)
        x = F.relu(x)
        x = self.pool1(x) # Max-pooling
        x = self.conv3(x) # Capas Convolucionales
        x = F.relu(x)
        x = self.conv4(x)
        x = F.relu(x)
        x = self.conv5(x)
        x = F.relu(x)
        x = self.pool2(x) # Max-pooling
        x = self.conv6(x) # Capas Convolucionales adicionales
        x = F.relu(x)
        x = self.conv7(x)
        x = F.relu(x)
        x = self.conv8(x)
        x = F.relu(x)
        x = self.pool3(x) # Max-pooling
        x = self.cyclic_pool(x) # Cyclic pooling
        x = self.flatten(x) # Flatten
        x = self.dense1(x)  # Dense layer (FC)
        x = F.relu(x)
        x = self.dropout(x) # Dropout
        x = self.dense2(x)  # Dense layer (FC)
        x = F.relu(x)
        x = self.dropout(x) #Dropout
        x = self.output_layer(x) #Output softmax
        return x

# %% [markdown]
# #Entrenamiento

# %%
# Número de épocas y tamaño de lote
num_epochs = 10
batch_size = 32

# Definir el modelo, optimizador y función de pérdida
model = SupernovaDetector()
optimizer = optim.Adam(model.parameters(), lr=0.001)
criterion = nn.CrossEntropyLoss()

# Entrenar el modelo
for epoch in range(num_epochs):
    start_time = time.time()
    running_loss = 0.0
    correct = 0
    total = 0

    for i, data in enumerate(train_loader, 0):
        inputs, labels = data

        # Poner a cero los gradientes
        optimizer.zero_grad()

        # Propagación hacia adelante
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        # Calcular estadísticas
        running_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

        # Imprimir estadísticas
        if i % 100 == 99:  # Imprimir cada 100 lotes
            print(f'Época [{epoch + 1}, Lote {i + 1}], Pérdida: {running_loss / 100:.3f}, Precisión: {100 * correct / total:.2f}%')
            running_loss = 0.0

    end_time = time.time()
    print(f'Tiempo de época: {end_time - start_time:.2f} segundos')

print('Entrenamiento finalizado')
# Out:
# Época [1, Lote 100], Pérdida: 1.607, Precisión: 22.09%
# Época [1, Lote 200], Pérdida: 1.575, Precisión: 24.20%
# Época [1, Lote 300], Pérdida: 1.552, Precisión: 25.62%
# Época [1, Lote 400], Pérdida: 1.358, Precisión: 27.84%
# Época [1, Lote 500], Pérdida: 1.243, Precisión: 29.59%
# Época [1, Lote 600], Pérdida: 1.202, Precisión: 30.85%
# Época [1, Lote 700], Pérdida: 1.187, Precisión: 32.00%
# Época [1, Lote 800], Pérdida: 1.126, Precisión: 33.30%
# Época [1, Lote 900], Pérdida: 1.104, Precisión: 34.19%
# Época [1, Lote 1000], Pérdida: 1.101, Precisión: 35.13%
# Época [1, Lote 1100], Pérdida: 1.069, Precisión: 36.30%
# Época [1, Lote 1200], Pérdida: 1.045, Precisión: 37.68%
# Época [1, Lote 1300], Pérdida: 1.044, Precisión: 38.98%
# Época [1, Lote 1400], Pérdida: 1.029, Precisión: 40.19%
# Época [1, Lote 1500], Pérdida: 0.966, Precisión: 41.56%
# Época [1, Lote 1600], Pérdida: 1.014, Precisión: 42.65%
# Época [1, Lote 1700], Pérdida: 0.948, Precisión: 43.73%
# Época [1, Lote 1800], Pérdida: 0.955, Precisión: 44.75%
# Época [1, Lote 1900], Pérdida: 0.872, Precisión: 45.92%
# Época [1, Lote 2000], Pérdida: 0.845, Precisión: 47.03%
# Época [1, Lote 2100], Pérdida: 0.884, Precisión: 47.96%
# Época [1, Lote 2200], Pérdida: 0.836, Precisión: 48.96%
# Tiempo de época: 301.15 segundos
# Época [2, Lote 100], Pérdida: 0.802, Precisión: 70.31%
# Época [2, Lote 200], Pérdida: 0.789, Precisión: 71.11%
# Época [2, Lote 300], Pérdida: 0.742, Precisión: 71.77%
# Época [2, Lote 400], Pérdida: 0.726, Precisión: 72.32%
# Época [2, Lote 500], Pérdida: 0.763, Precisión: 72.31%
# Época [2, Lote 600], Pérdida: 0.741, Precisión: 72.29%
# Época [2, Lote 700], Pérdida: 0.748, Precisión: 72.36%
# Época [2, Lote 800], Pérdida: 0.742, Precisión: 72.50%
# Época [2, Lote 900], Pérdida: 0.731, Precisión: 72.56%
# Época [2, Lote 1000], Pérdida: 0.712, Precisión: 72.76%
# Época [2, Lote 1100], Pérdida: 0.691, Precisión: 72.99%
# Época [2, Lote 1200], Pérdida: 0.715, Precisión: 73.04%
# Época [2, Lote 1300], Pérdida: 0.663, Precisión: 73.30%
# Época [2, Lote 1400], Pérdida: 0.708, Precisión: 73.43%
# Época [10, Lote 1800], Pérdida: 0.410, Precisión: 86.49%
# Época [10, Lote 1900], Pérdida: 0.358, Precisión: 86.60%
# Época [10, Lote 2000], Pérdida: 0.364, Precisión: 86.62%
# Época [10, Lote 2100], Pérdida: 0.358, Precisión: 86.68%
# Época [10, Lote 2200], Pérdida: 0.389, Precisión: 86.73%
# Tiempo de época: 276.24 segundos
# Entrenamiento finalizado

# %%
# Guardar el modelo
torch.save(model.state_dict(), 'supernova_detectorcapasadicionales.pth')

# Para descargar el modelo
from google.colab import files
files.download('supernova_detectorcapasadicionales.pth')
# 35min aprox.

# %% [markdown]
# #Evaluación del Modelo

# %%
# Definir una función para evaluar el modelo
def evaluate_model(model, data_loader):
    model.eval()  # Establecer el modelo en modo de evaluación
    correct = 0
    total = 0

    with torch.no_grad():
        for images, labels in data_loader:
            outputs = model(images)
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    accuracy = 100 * correct / total
    return accuracy

# Evaluar en el conjunto de prueba
test_accuracy = evaluate_model(model, test_loader)
print(f'Precisión en el conjunto de prueba: {test_accuracy:.2f}%')
# Out:
# Precisión en el conjunto de prueba: 84.20%

# %%
def evaluate_model_roc_confusion(model, data_loader):
    model.eval()
    all_labels = []
    all_scores = []

    with torch.no_grad():
        for inputs, labels in data_loader:
            outputs = model(inputs)
            all_labels.extend(labels.numpy())
            all_scores.extend(outputs.numpy())

    n_classes = len(np.unique(all_labels))
    fpr = dict()
    tpr = dict()
    roc_auc = dict()

    for i in range(n_classes):
        true_labels = np.array(all_labels) == i
        scores = [score[i] for score in all_scores]
        fpr[i], tpr[i], _ = roc_curve(true_labels, scores)
        roc_auc[i] = roc_auc_score(true_labels, scores)

    # Confusion matrix
    all_labels = np.array(all_labels)
    all_predictions = np.array(all_scores).argmax(axis=1)
    cm = confusion_matrix(all_labels, all_predictions)

    return fpr, tpr, roc_auc, cm

fpr, tpr, roc_auc, cm = evaluate_model_roc_confusion(model, test_loader)

# Plot ROC curves para cada clase
plt.figure(figsize=(8, 6))
n_classes = len(roc_auc)
for i in range(n_classes):
    plt.plot(fpr[i], tpr[i], lw=2, label=f'ROC curve (area = {roc_auc[i]:.2f}) for class {i}')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc='best')
plt.show()

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
# Normalizar la matriz de confusión
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

labels = ['AGN', 'SN', 'VS', 'asteroid', 'bogus']

plt.figure(figsize=(10, 7))
sns.heatmap(cm_normalized, annot=True, fmt=".2f", cmap="Blues", xticklabels=labels, yticklabels=labels)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %%
def evaluate_model_metrics(model, data_loader):
    model.eval()
    all_labels = []
    all_predictions = []

    with torch.no_grad():
        for inputs, labels in data_loader:
            outputs = model(inputs)
            _, predicted = torch.max(outputs, 1)

            all_labels.extend(labels.numpy())
            all_predictions.extend(predicted.numpy())

    # Convertir las listas a arrays numpy
    y_true = np.array(all_labels)
    y_pred = np.array(all_predictions)

    # Calcular métricas
    accuracy = accuracy_score(y_true, y_pred)
    precision_per_class = precision_score(y_true, y_pred, average=None)
    recall_per_class = recall_score(y_true, y_pred, average=None)
    f1_per_class = f1_score(y_true, y_pred, average=None)
    conf_matrix = confusion_matrix(y_true, y_pred)

    print(f"Accuracy: {accuracy}")
    print(f"Precision por clase: {precision_per_class}")
    print(f"Recall por clase: {recall_per_class}")
    print(f"F1 Score por clase: {f1_per_class}")
    print(f"Matriz de Confusión:\n{conf_matrix}")

    # Retornar las métricas
    return accuracy, precision_per_class, recall_per_class, f1_per_class, conf_matrix

# Llamar a la función para obtener las métricas
accuracy, precision, recall, f1, conf_matrix = evaluate_model_metrics(model, test_loader)
# Out:
# Accuracy: 0.842
# Precision por clase: [0.8        0.82608696 0.90804598 0.79464286 0.8989899 ]
# Recall por clase: [0.88 0.76 0.79 0.89 0.89]
# F1 Score por clase: [0.83809524 0.79166667 0.84491979 0.83962264 0.89447236]
# Matriz de Confusión:
# [[88  5  6  0  1]
#  [ 4 76  1 16  3]
#  [17  0 79  3  1]
#  [ 1  5  0 89  5]
#  [ 0  6  1  4 89]]

# %% [markdown]
# # Arquitectura Crop, Zero Padding, Capas Adicionales, Zoom

# %% [markdown]
# # Arquitectura Capas Adicionales, Rotaciones y Zoom
#
# | Capa | Tipo de Capa                | Entradas | Salidas | Kernel/Pool | Stride | Padding |
# |------|-----------------------------|----------|---------|-------------|--------|---------|
# | 1    | Rotaciones y Zoom        | 3        | 3       | 3x3         | 1      | 1       |
# | 2    | Conv1                       | 3        | 32      | 4x4         | 1      | 2       |
# | 3    | Conv2                       | 32       | 32      | 3x3         | 1      | 1       |
# | 4    | MaxPool1                     | -       | -       | 2x2         | 2      | -       |
# | 5    | Conv3                       | 32       | 64      | 3x3         | 1      | 1       |
# | 6    | Conv4                       | 64       | 64      | 3x3         | 1      | 1       |
# | 7    | Conv5                       | 64       | 64      | 3x3         | 1      | 1       |
# | 8    | MaxPool2                     | -       | -       | 2x2         | 2      | -       |
# | 9    | Conv6                       | 64       | 128     | 3x3         | 1      | 1       |
# | 10   | Conv7                       | 128      | 128     | 3x3         | 1      | 1       |
# | 11   | Conv8                       | 128      | 128     | 3x3         | 1      | 1       |
# | 12   | MaxPool3                     | -       | -       | 2x2         | 2      | -       |
# | 13   | Cyclic Pooling              | -       | -       | -           | -      | -       |
# | 14   | Flatten                     | -       | -       | -           | -      | -       |
# | 15   | Dense1                      | 256      | 64      | -           | -      | -       |
# | 16   | Dense2                      | 64       | 64      | -           | -      | -       |
# | 17   | Salida                      | 64       | 5       | -           | -      | -       |
# | 18   | Dropout                     | -       | -       | -           | -      | -       |

# %%
def Augmentation(x_0, zoom_factor=1.2):
    x_1 = x_0.clone()
    x_2 = x_0.clone()
    x_3 = x_0.clone()

    for i in range(x_0.shape[0]):
        for j in range(3):
            # Rotaciones
            x_1[i, j, :, :] = torch.rot90(x_0[i, j, :, :], 1, [0, 1])
            x_2[i, j, :, :] = torch.rot90(x_0[i, j, :, :], 2, [0, 1])
            x_3[i, j, :, :] = torch.rot90(x_0[i, j, :, :], 3, [0, 1])

            # Zoom
            zoomed_image = TF.affine(x_0[i, j, :, :].unsqueeze(0), angle=0, translate=(0, 0), scale=zoom_factor, shear=0)
            x_1[i, j, :, :] = zoomed_image.squeeze(0)

    return [x_0, x_1, x_2, x_3]

# %%
class CyclicPool(nn.Module):
    def __init__(self, in_channels):
        super(CyclicPool, self).__init__()
        self.in_channels = in_channels
        self.avg_pool = nn.AvgPool2d(kernel_size=2, stride=2)
        self.max_pool = nn.MaxPool2d(kernel_size=2, stride=2)

    def forward(self, x):
        x_avg = self.avg_pool(x)
        x_max = self.max_pool(x)
        x = torch.cat([x_avg, x_max], dim=1)
        return x

# %%
class SupernovaDetector(nn.Module):
    def __init__(self, zoom_factor=1.2):
        super(SupernovaDetector, self).__init__()
        self.zoom_factor = zoom_factor

        # Aumentación de datos (rotaciones y zoom)
        self.augmentation = nn.Sequential(
            nn.Conv2d(3, 3, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.Conv2d(3, 3, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
        )

        # Capas Convolucionales
        self.conv1 = nn.Conv2d(3, 32, kernel_size=4, stride=1, padding=2)
        self.conv2 = nn.Conv2d(32, 32, kernel_size=3, stride=1, padding=1)
        # Max-pooling
        self.pool1 = nn.MaxPool2d(2, 2)
        # Capas Convolucionales adicionales
        self.conv3 = nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1)
        self.conv4 = nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=1)
        self.conv5 = nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=1)
        # Max-pooling
        self.pool2 = nn.MaxPool2d(2, 2)
        # Capas Convolucionales adicionales
        self.conv6 = nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1)
        self.conv7 = nn.Conv2d(128, 128, kernel_size=3, stride=1, padding=1)
        self.conv8 = nn.Conv2d(128, 128, kernel_size=3, stride=1, padding=1)
        # Max-pooling
        self.pool3 = nn.MaxPool2d(2, 2)
        # Cyclic pooling
        self.cyclic_pool = CyclicPool(128)
        # Flatten
        self.flatten = nn.Flatten()
        # Dense layer (FC)
        self.dense1 = nn.Linear(256, 64)
        self.dense2 = nn.Linear(64, 64)
        # Output dropout softmax
        self.output_layer = nn.Linear(64, 5)
        self.dropout = nn.Dropout(p=0.5)

    def forward(self, x):
        # Aplicar rotaciones y zoom al inicio
        x_augmented_list = Augmentation(x, zoom_factor=self.zoom_factor)
        # Concatenar a lo largo de la dimensión del lote (batch dimension)
        x_augmented = torch.cat(x_augmented_list, dim=0)
        x = self.conv1(x)  # Capas Convolucionales
        x = F.relu(x)
        x = self.conv2(x)
        x = F.relu(x)
        x = self.pool1(x) # Max-pooling
        x = self.conv3(x) # Capas Convolucionales
        x = F.relu(x)
        x = self.conv4(x)
        x = F.relu(x)
        x = self.conv5(x)
        x = F.relu(x)
        x = self.pool2(x) # Max-pooling
        x = self.conv6(x) # Capas Convolucionales adicionales
        x = F.relu(x)
        x = self.conv7(x)
        x = F.relu(x)
        x = self.conv8(x)
        x = F.relu(x)
        x = self.pool3(x) # Max-pooling
        x = self.cyclic_pool(x) # Cyclic pooling
        x = self.flatten(x) # Flatten
        x = self.dense1(x)  # Dense layer (FC)
        x = F.relu(x)
        x = self.dropout(x) # Dropout
        x = self.dense2(x)  # Dense layer (FC)
        x = F.relu(x)
        x = self.dropout(x) #Dropout
        x = self.output_layer(x) #Output softmax
        return x

# %% [markdown]
# # Entrenamiento

# %%
# Número de épocas y tamaño de lote
num_epochs = 10
batch_size = 32

# Definir el modelo, optimizador y función de pérdida
model = SupernovaDetector()
optimizer = optim.Adam(model.parameters(), lr=0.001)
criterion = nn.CrossEntropyLoss()

# Entrenar el modelo
for epoch in range(num_epochs):
    start_time = time.time()
    running_loss = 0.0
    correct = 0
    total = 0

    for i, data in enumerate(train_loader, 0):
        inputs, labels = data

        # Poner a cero los gradientes
        optimizer.zero_grad()

        # Propagación hacia adelante
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        # Calcular estadísticas
        running_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

        # Imprimir estadísticas
        if i % 100 == 99:  # Imprimir cada 100 lotes
            print(f'Época [{epoch + 1}, Lote {i + 1}], Pérdida: {running_loss / 100:.3f}, Precisión: {100 * correct / total:.2f}%')
            running_loss = 0.0

    end_time = time.time()
    print(f'Tiempo de época: {end_time - start_time:.2f} segundos')

print('Entrenamiento finalizado')
# Out:
# Época [1, Lote 100], Pérdida: 1.603, Precisión: 21.69%
# Época [1, Lote 200], Pérdida: 1.540, Precisión: 25.50%
# Época [1, Lote 300], Pérdida: 1.518, Precisión: 26.97%
# Época [1, Lote 400], Pérdida: 1.491, Precisión: 28.89%
# Época [1, Lote 500], Pérdida: 1.470, Precisión: 30.63%
# Época [1, Lote 600], Pérdida: 1.433, Precisión: 31.46%
# Época [1, Lote 700], Pérdida: 1.403, Precisión: 32.28%
# Época [1, Lote 800], Pérdida: 1.317, Precisión: 33.23%
# Época [1, Lote 900], Pérdida: 1.244, Precisión: 34.31%
# Época [1, Lote 1000], Pérdida: 1.179, Precisión: 35.41%
# Época [1, Lote 1100], Pérdida: 1.170, Precisión: 36.25%
# Época [1, Lote 1200], Pérdida: 1.145, Precisión: 37.08%
# Época [1, Lote 1300], Pérdida: 1.090, Precisión: 38.08%
# Época [1, Lote 1400], Pérdida: 1.023, Precisión: 39.05%
# Época [1, Lote 1500], Pérdida: 1.043, Precisión: 39.91%
# Época [1, Lote 1600], Pérdida: 0.974, Precisión: 41.15%
# Época [1, Lote 1700], Pérdida: 0.946, Precisión: 42.33%
# Época [1, Lote 1800], Pérdida: 0.947, Precisión: 43.53%
# Época [1, Lote 1900], Pérdida: 0.919, Precisión: 44.63%
# Época [1, Lote 2000], Pérdida: 0.893, Precisión: 45.68%
# Época [1, Lote 2100], Pérdida: 0.821, Precisión: 46.83%
# Época [1, Lote 2200], Pérdida: 0.812, Precisión: 47.86%
# Tiempo de época: 333.59 segundos
# Época [2, Lote 100], Pérdida: 0.855, Precisión: 69.47%
# Época [2, Lote 200], Pérdida: 0.819, Precisión: 69.53%
# Época [2, Lote 300], Pérdida: 0.789, Precisión: 70.30%
# Época [2, Lote 400], Pérdida: 0.799, Precisión: 70.51%
# Época [2, Lote 500], Pérdida: 0.751, Precisión: 70.79%
# Época [2, Lote 600], Pérdida: 0.767, Precisión: 70.84%
# Época [2, Lote 700], Pérdida: 0.747, Precisión: 71.04%
# Época [2, Lote 800], Pérdida: 0.764, Precisión: 71.17%
# Época [2, Lote 900], Pérdida: 0.718, Precisión: 71.57%
# Época [2, Lote 1000], Pérdida: 0.750, Precisión: 71.64%
# Época [10, Lote 1400], Pérdida: 0.404, Precisión: 85.51%
# Época [10, Lote 1500], Pérdida: 0.414, Precisión: 85.56%
# Época [10, Lote 1600], Pérdida: 0.442, Precisión: 85.51%
# Época [10, Lote 1700], Pérdida: 0.405, Precisión: 85.52%
# Época [10, Lote 1800], Pérdida: 0.364, Precisión: 85.62%
# Época [10, Lote 1900], Pérdida: 0.440, Precisión: 85.59%
# Época [10, Lote 2000], Pérdida: 0.400, Precisión: 85.60%
# Época [10, Lote 2100], Pérdida: 0.425, Precisión: 85.65%
# Época [10, Lote 2200], Pérdida: 0.404, Precisión: 85.68%
# Tiempo de época: 319.88 segundos
# Entrenamiento finalizado

# %%
# Guardar el modelo
torch.save(model.state_dict(), 'supernova_detectorzoomcapasadicionales.pth')

# Para descargar el modelo
from google.colab import files
files.download('supernova_detectorzoomcapasadicionales.pth')
# 35min aprox.

# %% [markdown]
# # Evaluación del Modelo

# %%
# Definir una función para evaluar el modelo
def evaluate_model(model, data_loader):
    model.eval()  # Establecer el modelo en modo de evaluación
    correct = 0
    total = 0

    with torch.no_grad():
        for images, labels in data_loader:
            outputs = model(images)
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    accuracy = 100 * correct / total
    return accuracy

# Evaluar en el conjunto de prueba
test_accuracy = evaluate_model(model, test_loader)
print(f'Precisión en el conjunto de prueba: {test_accuracy:.2f}%')
# Out:
# Precisión en el conjunto de prueba: 83.80%

# %%
def evaluate_model_roc_confusion(model, data_loader):
    model.eval()
    all_labels = []
    all_scores = []

    with torch.no_grad():
        for inputs, labels in data_loader:
            outputs = model(inputs)
            all_labels.extend(labels.numpy())
            all_scores.extend(outputs.numpy())

    n_classes = len(np.unique(all_labels))
    fpr = dict()
    tpr = dict()
    roc_auc = dict()

    for i in range(n_classes):
        true_labels = np.array(all_labels) == i
        scores = [score[i] for score in all_scores]
        fpr[i], tpr[i], _ = roc_curve(true_labels, scores)
        roc_auc[i] = roc_auc_score(true_labels, scores)

    # Confusion matrix
    all_labels = np.array(all_labels)
    all_predictions = np.array(all_scores).argmax(axis=1)
    cm = confusion_matrix(all_labels, all_predictions)

    return fpr, tpr, roc_auc, cm

fpr, tpr, roc_auc, cm = evaluate_model_roc_confusion(model, test_loader)

# Plot ROC curves para cada clase
plt.figure(figsize=(8, 6))
n_classes = len(roc_auc)
for i in range(n_classes):
    plt.plot(fpr[i], tpr[i], lw=2, label=f'ROC curve (area = {roc_auc[i]:.2f}) for class {i}')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc='best')
plt.show()

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
# Normalizar la matriz de confusión
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

labels = ['AGN', 'SN', 'VS', 'asteroid', 'bogus']

plt.figure(figsize=(10, 7))
sns.heatmap(cm_normalized, annot=True, fmt=".2f", cmap="Blues", xticklabels=labels, yticklabels=labels)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %%
def evaluate_model_metrics(model, data_loader):
    model.eval()
    all_labels = []
    all_predictions = []

    with torch.no_grad():
        for inputs, labels in data_loader:
            outputs = model(inputs)
            _, predicted = torch.max(outputs, 1)

            all_labels.extend(labels.numpy())
            all_predictions.extend(predicted.numpy())

    # Convertir las listas a arrays numpy
    y_true = np.array(all_labels)
    y_pred = np.array(all_predictions)

    # Calcular métricas
    accuracy = accuracy_score(y_true, y_pred)
    precision_per_class = precision_score(y_true, y_pred, average=None)
    recall_per_class = recall_score(y_true, y_pred, average=None)
    f1_per_class = f1_score(y_true, y_pred, average=None)
    conf_matrix = confusion_matrix(y_true, y_pred)

    print(f"Accuracy: {accuracy}")
    print(f"Precision por clase: {precision_per_class}")
    print(f"Recall por clase: {recall_per_class}")
    print(f"F1 Score por clase: {f1_per_class}")
    print(f"Matriz de Confusión:\n{conf_matrix}")

    # Retornar las métricas
    return accuracy, precision_per_class, recall_per_class, f1_per_class, conf_matrix

# Llamar a la función para obtener las métricas
accuracy, precision, recall, f1, conf_matrix = evaluate_model_metrics(model, test_loader)
# Out:
# Accuracy: 0.838
# Precision por clase: [0.78947368 0.8372093  0.90804598 0.80530973 0.87      ]
# Recall por clase: [0.9  0.72 0.79 0.91 0.87]
# F1 Score por clase: [0.8411215  0.77419355 0.84491979 0.85446009 0.87      ]
# Matriz de Confusión:
# [[90  2  6  0  2]
#  [ 4 72  1 18  5]
#  [19  1 79  0  1]
#  [ 0  4  0 91  5]
#  [ 1  7  1  4 87]]
